# %%
import numpy as np
from numpy.random import randn

# %%
N = 1000
contador = 0

# %%
for i in range(N):
    x = randn()
    if x > - 1 and x < 1:
        contador = + 1
    print(x)
respuesta = (contador/N)*100
distancia = respuesta - 68.2
# Out:
# 0.049530307890292086
# 0.38261607039079704
# 0.4083105081056014
# -0.9636879699230869
# -0.4036091865412735
# -1.711460648744647
# 0.73757976345611
# 0.48117771224348677
# -0.33267975508603703
# 0.23261586235450585
# -0.4304920890541207
# -0.5872298916892322
# 1.013316780804632
# -1.220191400572678
# -0.08952922688613933
# 1.3025550522325866
# -0.19704243373428199
# -0.8325153061426204
# 0.5383044779370731
# 0.842399223297425
# -0.34474719820312927
# 0.04021184136723778
# -1.0718902232184921
# 0.21804318543198414
# -1.0078580482907642
# 0.7990586973395577
# 0.6290127424489869
# 1.0704637079332606
# -1.1193319170936835
# 1.5657980438468804
# -0.17949112206387563
# 1.190905023703807
# 1.3445410367458905
# 0.6471797236291634
# -0.07258087935622738
# -0.3411970678259751
# 0.31490842235288724
# -0.3051002082951187
# -0.4920650165707142
# -0.8788879477033896
# -1.4424379926356892
# -1.5416456771524236
# -0.6932397640768551
# -0.29396431447480803
# -0.6097275116642838
# -2.9929681918014897
# ...

# %%
print(respuesta)
print(distancia)
# Out:
# 0.1
# -68.10000000000001
